# %% [markdown]
# <div style="position: absolute; top: 0; left: 0; font-family: 'Garamond'; font-size: 16px;">
#     <a href="https://github.com/patriciaapenat" style="text-decoration: none; color: inherit;">Patricia Peña Torres</a>
# </div>
#
# <div align="center" style="font-family: 'Garamond'; font-size: 48px;">
#     <strong>Proyecto final, BRFSS-clustering</strong>
# </div>
#
# <div align="center" style="font-family: 'Garamond'; font-size: 36px;">
#     <strong>1. Transformación inicial</strong>
# </div>

# %% [markdown]
# _______________________

# %% [markdown]
# <div style="font-family: 'Garamond'; font-size: 14px;">
#     <normal>Los datos se encontraban en formato xpt pensados para ser tratados con SAS, no hay una función oficial de Spark para leer archivos de origen xpt y tras probar algunos paquetes que son proyectos personales de múltiples personas en GitHub y por tanto no tienen mantenimiente, pensé que lo mejor sería transformarlos con pandas a csv</normal>
# </div>

# %%
import pandas as pd
import os

# Cargar el archivo XPT en un DataFrame de pandas
_22 = pd.read_sas(r"C:\Users\patri\OneDrive - UAB\Documentos\GitHub\BRFSS-clustering\raw_data\LLCP2022XPT\LLCP2022.XPT", format='xport')

# %%
_22
# Out:
#         _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 0          1.0     1.0  b'02032022'  b'02'  b'03'  b'2022'    1100.0
# 1          1.0     1.0  b'02042022'  b'02'  b'04'  b'2022'    1100.0
# 2          1.0     1.0  b'02022022'  b'02'  b'02'  b'2022'    1100.0
# 3          1.0     1.0  b'02032022'  b'02'  b'03'  b'2022'    1100.0
# 4          1.0     1.0  b'02022022'  b'02'  b'02'  b'2022'    1100.0
# ...        ...     ...          ...    ...    ...      ...       ...
# 445127    78.0    11.0  b'12192022'  b'12'  b'19'  b'2022'    1100.0
# 445128    78.0    11.0  b'12212022'  b'12'  b'21'  b'2022'    1100.0
# 445129    78.0    11.0  b'11292022'  b'11'  b'29'  b'2022'    1100.0
# 445130    78.0    11.0  b'12082022'  b'12'  b'08'  b'2022'    1100.0
# 445131    78.0    11.0  b'12142022'  b'12'  b'14'  b'2022'    1100.0
#
#                 SEQNO          _PSU  CTELENM1  ...  _SMOKGRP  _LCSREC  \
# ...

# %%
csv_file_path = r"C:\Users\patri\OneDrive - UAB\Documentos\GitHub\BRFSS-clustering\raw_data\BRFSS_2022.csv"

# Verifica si el archivo CSV ya existe
if os.path.exists(csv_file_path):
    print(f"¡Advertencia! El archivo CSV '{csv_file_path}' ya existe. No se ha sobrescrito. Por favor, elija otro nombre.")
else:
    # Guarda el archivo CSV si no existe
    df.to_csv(csv_file_path, index=False)
    print(f"El DataFrame se ha guardado como CSV en: {csv_file_path}")
# Out:
# ¡Advertencia! El archivo CSV 'C:\Users\patri\OneDrive - UAB\Documentos\GitHub\BRFSS-clustering\raw_data\BRFSS_2022.csv' ya existe. No se ha sobrescrito. Por favor, elija otro nombre.
